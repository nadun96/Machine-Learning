# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/diabetes (1).csv")

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset2 = pd.read_csv("/content/Placement_Dataset.csv")

# %%
dataset2.head(15)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 2       3      M  65.00  Central  68.00  Central      Arts     64.00
# 3       4      M  56.00  Central  52.00  Central   Science     52.00
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5       6      M  55.00   Others  49.80   Others   Science     67.25
# 6       7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7       8      M  82.00  Central  64.00  Central   Science     66.00
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9      10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10     11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11     12      M  69.60  Central  68.40  Central  Commerce     78.30
# 12     13      F  47.00  Central  55.00   Others   Science     65.00
# ...

# %%
dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
dataset2.tail(13)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 202    203      M  70.00  Central  63.00  Central   Science     66.00
# 203    204      M  55.68   Others  61.33   Others  Commerce     56.87
# 204    205      F  74.00   Others  73.00   Others  Commerce     73.00
# 205    206      M  61.00   Others  62.00   Others  Commerce     65.00
# 206    207      M  41.00  Central  42.00  Central   Science     60.00
# 207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 208    209      F  43.00  Central  60.00   Others   Science     65.00
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset2.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset2.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (768, 9)

# %%
dataset2.shape
# Out:
# (215, 15)

# %%
dataset.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
dataset["Glucose"]
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
dataset.Glucose
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
dataset[['Glucose', 'BloodPressure', 'SkinThickness']]
# Out:
#      Glucose  BloodPressure  SkinThickness
# 0        148             72             35
# 1         85             66             29
# 2        183             64              0
# 3         89             66             23
# 4        137             40             35
# ..       ...            ...            ...
# 763      101             76             48
# 764      122             70             27
# 765      121             72             23
# 766      126             60              0
# 767       93             70             31
#
# [768 rows x 3 columns]

# %%
dataset2.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
dataset2.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
dataset2["status"].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
dataset2["hsc_s"].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
dataset2["status"].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
dataset["Glucose"].mean()
# Out:
# 120.89453125

# %%
dataset["Glucose"].median()
# Out:
# 117.0

# %%
new = dataset.Glucose

# %%
new
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
new[3]
# Out:
# 89

# %%
new[1:5]
# Out:
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
new[1:20:2]
# Out:
# 1      85
# 3      89
# 5     116
# 7     115
# 9     125
# 11    168
# 13    189
# 15    100
# 17    107
# 19    115
# Name: Glucose, dtype: int64

# %%
dataset.loc["d"]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Name: 2, dtype: float64

# %%
dataset.iloc[4]
# Out:
# Pregnancies                   0.000
# Glucose                     137.000
# BloodPressure                40.000
# SkinThickness                35.000
# Insulin                     168.000
# BMI                          43.100
# DiabetesPedigreeFunction      2.288
# Age                          33.000
# Outcome                       1.000
# Name: 4, dtype: float64

# %%
dataset.iloc[3:9]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1

# %%
dataset["new column"] = 1

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  new column
# 0                     0.627   50        1           1
# 1                     0.351   31        0           1
# 2                     0.672   32        1           1
# 3                     0.167   21        0           1
# 4                     2.288   33        1           1

# %%
dataset["new column"].value_counts()
# Out:
# 1    768
# Name: new column, dtype: int64

# %%
dataset["newcolumn"] = dataset["Glucose"] / 100

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  new column  newcolumn
# 0                     0.627   50        1        1.48       1.48
# 1                     0.351   31        0        0.85       0.85
# 2                     0.672   32        1        1.83       1.83
# 3                     0.167   21        0        0.89       0.89
# 4                     2.288   33        1        1.37       1.37

# %%
dataset.drop(["newcolumn", "Pregnancies"], axis=1, inplace=True)

# %%
dataset.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  new column
# 0                     0.627   50        1        1.48
# 1                     0.351   31        0        0.85
# 2                     0.672   32        1        1.83
# 3                     0.167   21        0        0.89
# 4                     2.288   33        1        1.37

# %%
dataset.drop(["Glucose"], axis=1, inplace=True)

# %%
new
# Out:
#      BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  \
# 0               72             35        0  33.6                     0.627
# 1               66             29        0  26.6                     0.351
# 3               66             23       94  28.1                     0.167
# 5               74              0        0  25.6                     0.201
# 6               50             32       88  31.0                     0.248
# ..             ...            ...      ...   ...                       ...
# 763             76             48      180  32.9                     0.171
# 764             70             27        0  36.8                     0.340
# 765             72             23      112  26.2                     0.245
# 766             60              0        0  30.1                     0.349
# 767             70             31        0  30.4                     0.315
#
#      Age  Outcome  new column
# 0     50        1        1.48
# ...

# %%
dataset.head()
# Out:
#    BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0             72             35        0  33.6                     0.627   50
# 1             66             29        0  26.6                     0.351   31
# 3             66             23       94  28.1                     0.167   21
# 5             74              0        0  25.6                     0.201   30
# 6             50             32       88  31.0                     0.248   26
#
#    Outcome  new column
# 0        1        1.48
# 1        0        0.85
# 3        0        0.89
# 5        0        1.16
# 6        1        0.78

# %%
dataset.drop([2,4], axis = 0, inplace=True)

# %%
dataset.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 3       89             66             23       94  28.1
# 5      116             74              0        0  25.6
# 6       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome  new column
# 0                     0.627   50        1        1.48
# 1                     0.351   31        0        0.85
# 3                     0.167   21        0        0.89
# 5                     0.201   30        0        1.16
# 6                     0.248   26        1        0.78

# %%
dataset.rename(columns={"BloodPressure":"BP", "DiabetesPedigreeFunction":"DPF"}, inplace=True)

# %%
dataset.head()
# Out:
#    BP  SkinThickness  Insulin   BMI    DPF  Age  Outcome  new column
# 0  72             35        0  33.6  0.627   50        1        1.48
# 1  66             29        0  26.6  0.351   31        0        0.85
# 3  66             23       94  28.1  0.167   21        0        0.89
# 5  74              0        0  25.6  0.201   30        0        1.16
# 6  50             32       88  31.0  0.248   26        1        0.78

# %%
one = dataset[["Age","Outcome"]]

# %%
two = dataset[["BMI", "Insulin"]]

# %%
pd.concat([one, two], axis =1)
# Out:
#      Age  Outcome   BMI  Insulin
# 0     50        1  33.6        0
# 1     31        0  26.6        0
# 3     21        0  28.1       94
# 5     30        0  25.6        0
# 6     26        1  31.0       88
# ..   ...      ...   ...      ...
# 763   63        0  32.9      180
# 764   27        0  36.8        0
# 765   30        0  26.2      112
# 766   47        1  30.1        0
# 767   23        0  30.4        0
#
# [766 rows x 4 columns]

# %%
dataset2.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
dataset2.set_index(dataset2["degree_t"], inplace=True)

# %%
dataset2.head()
# Out:
#            sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# degree_t
# Sci&Tech       1      M  67.00   Others  91.00   Others  Commerce     58.00
# Sci&Tech       2      M  79.33  Central  78.33   Others   Science     77.48
# Comm&Mgmt      3      M  65.00  Central  68.00  Central      Arts     64.00
# Sci&Tech       4      M  56.00  Central  52.00  Central   Science     52.00
# Comm&Mgmt      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#             degree_t workex  etest_p specialisation  mba_p      status  \
# degree_t
# Sci&Tech    Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# Sci&Tech    Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# Comm&Mgmt  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# Sci&Tech    Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# Comm&Mgmt  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed
#
#              salary
# degree_t
# Sci&Tech   270000.0
# ...

# %%
dataset2.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset2["salary"].fillna(0, inplace=True)

# %%
dataset2.head()
# Out:
#            sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# degree_t
# Sci&Tech       1      M  67.00   Others  91.00   Others  Commerce     58.00
# Sci&Tech       2      M  79.33  Central  78.33   Others   Science     77.48
# Comm&Mgmt      3      M  65.00  Central  68.00  Central      Arts     64.00
# Sci&Tech       4      M  56.00  Central  52.00  Central   Science     52.00
# Comm&Mgmt      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#             degree_t workex  etest_p specialisation  mba_p      status  \
# degree_t
# Sci&Tech    Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# Sci&Tech    Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# Comm&Mgmt  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# Sci&Tech    Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# Comm&Mgmt  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed
#
#              salary
# degree_t
# Sci&Tech   270000.0
# ...

# %%
dataset2.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset3 = pd.read_csv("/content/Placement_Dataset.csv")

# %%
dataset3.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset3.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
dataset3["salary"].mean()
# Out:
# 288655.4054054054

# %%
dataset3["salary"].fillna(dataset3["salary"].mean(), inplace=True)

# %%
dataset3["salary"].median()
# Out:
# 265000.0

# %%
dataset3["salary"].mode()
# Out:
# 0    300000.0
# dtype: float64

# %%
dataset3.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
dataset3.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset4 = pd.read_csv("/content/Placement_Dataset.csv")

# %%
dataset4.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset4.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
dataset4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset4.dropna(inplace=True)

# %%
dataset4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 0 to 213
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           148 non-null    int64
#  1   gender          148 non-null    object
#  2   ssc_p           148 non-null    float64
#  3   ssc_b           148 non-null    object
#  4   hsc_p           148 non-null    float64
#  5   hsc_b           148 non-null    object
#  6   hsc_s           148 non-null    object
#  7   degree_p        148 non-null    float64
#  8   degree_t        148 non-null    object
#  9   workex          148 non-null    object
#  10  etest_p         148 non-null    float64
#  11  specialisation  148 non-null    object
#  12  mba_p           148 non-null    float64
#  13  status          148 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 18.5+ KB

# %%
dataset4.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80  Placed  250000.0
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50  Placed  425000.0
# 7   Sci&Tech    Yes     67.0        Mkt&Fin  62.14  Placed  252000.0

# %%
dataset4.duplicated().sum()
# Out:
# 0

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.drop_duplicates(inplace=True)
